# %%
import matplotlib.pyplot as plt
from astropy.coordinates import ICRS, Galactic, GalacticLSR, Galactocentric
import astropy.units as u
import astropy.coordinates as apycoords
import pandas as pd
from matplotlib import rcParams


rcParams.update({'figure.autolayout': True})
import seaborn as sns
import statistics as stat
import numpy as np
from matplotlib.figure import figaspect
#import plotly/
import scipy
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
from astropy.coordinates import SkyCoord
from astropy.coordinates import SkyCoord
from galpy.orbit import Orbit
from galpy.potential import MWPotential2014 
import plotly
from galpy.potential import NFWPotential, HernquistPotential, MiyamotoNagaiPotential
import plotly.express as px
from numpy.polynomial import Polynomial

# %%
df1 =  pd.read_csv('data_panels_ABCDE/OB_Region_A.csv')
y1_A=df1.y.values
vz1_A=df1.vz.values
err1_A=df1.error.values

df2 =  pd.read_csv('data_panels_ABCDE/UMS_Region_A.csv')
y2_A=df2.y.values
vz2_A=df2.vz.values
err2_A=df2.error.values


df3 =  pd.read_csv('data_panels_ABCDE/Giants_Region_A.csv')
y3_A=df3.y.values
vz3_A=df3.vz.values
err3_A=df3.error.values

# Region B


df1 =  pd.read_csv('data_panels_ABCDE/OB_Region_B.csv')
y1_B=df1.y.values
vz1_B=df1.vz.values
err1_B=df1.error.values

df2 =  pd.read_csv('data_panels_ABCDE/UMS_Region_B.csv')
y2_B=df2.y.values
vz2_B=df2.vz.values
err2_B=df2.error.values


df3 =  pd.read_csv('data_panels_ABCDE/Giants_Region_B.csv')
y3_B=df3.y.values
vz3_B=df3.vz.values
err3_B=df3.error.values

# Region C


df1 =  pd.read_csv('data_panels_ABCDE/OB_Region_C.csv')
y1_C=df1.y.values
vz1_C=df1.vz.values
err1_C=df1.error.values

df2 =  pd.read_csv('data_panels_ABCDE/UMS_Region_C.csv')
y2_C=df2.y.values
vz2_C=df2.vz.values
err2_C=df2.error.values


df3 =  pd.read_csv('data_panels_ABCDE/Giants_Region_C.csv')
y3_C=df3.y.values
vz3_C=df3.vz.values
err3_C=df3.error.values


# Region D


df1 =  pd.read_csv('data_panels_ABCDE/OB_Region_D.csv')
y1_D=df1.y.values
vz1_D=df1.vz.values
err1_D=df1.error.values

df2 =  pd.read_csv('data_panels_ABCDE/UMS_Region_D.csv')
y2_D=df2.y.values
vz2_D=df2.vz.values
err2_D=df2.error.values


df3 =  pd.read_csv('data_panels_ABCDE/Giants_Region_D.csv')
y3_D=df3.y.values
vz3_D=df3.vz.values
err3_D=df3.error.values


# Region E


df1 =  pd.read_csv('data_panels_ABCDE/OB_Region_E.csv')
y1_E=df1.y.values
vz1_E=df1.vz.values
err1_E=df1.error.values

df2 =  pd.read_csv('data_panels_ABCDE/UMS_Region_E.csv')
y2_E=df2.y.values
vz2_E=df2.vz.values
err2_E=df2.error.values


df3 =  pd.read_csv('data_panels_ABCDE/Giants_Region_E.csv')
y3_E=df3.y.values
vz3_E=df3.vz.values
err3_E=df3.error.values

# %%
w, h = figaspect(1/2)

fig, (ax1,ax2,ax3,ax4,ax5) = plt.subplots(nrows=5, ncols=1, dpi=100,figsize=(8,15),sharey=True)
fig.set_tight_layout(False)
fig.subplots_adjust(hspace=0, wspace=0)

#Axis1

ax1.errorbar(y1_A/1000,vz1_A,yerr=err1_A,ecolor='black', color='mediumvioletred',label='OB stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax1.errorbar(y2_A/1000,vz2_A,yerr=err2_A,ecolor='black', color='blue',label='UMS stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax1.errorbar(y3_A/1000,vz3_A,yerr=err3_A,ecolor='black',color='orangered',label='Giant stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax1.tick_params(axis='y')
ax1.axhline(y=0,color='grey')
ax1.legend(fontsize=9,loc=1)

#Axis 2

ax2.errorbar(y1_B/1000,vz1_B,yerr=err1_B,ecolor='black', color='mediumvioletred',label='OB stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax2.errorbar(y2_B/1000,vz2_B,yerr=err2_B,ecolor='black', color='blue',label='UMS stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax2.errorbar(y3_B/1000,vz3_B,yerr=err3_B,ecolor='black', color='orangered',label='Giant stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax2.tick_params(axis='y')
ax2.axhline(y=0,color='grey')
ax2.legend(fontsize=9,loc=1)




#Axis C


ax3.errorbar(y1_C/1000,vz1_C,yerr=err1_C,ecolor='black', color='mediumvioletred',label='OB stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax3.errorbar(y2_C/1000,vz2_C,yerr=err2_C,ecolor='black', color='blue',label='UMS stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax3.errorbar(y3_C/1000,vz3_C,yerr=err3_C,ecolor='black', color='orangered',label='Giant stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax3.tick_params(axis='y')
ax3.axhline(y=0,color='grey')
ax3.legend(fontsize=9,loc=1)


#Axis D


ax4.errorbar(y1_D/1000,vz1_D,yerr=err1_D,ecolor='black', color='mediumvioletred',label='OB stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax4.errorbar(y2_D/1000,vz2_D,yerr=err2_D,ecolor='black', color='blue',label='UMS stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax4.errorbar(y3_D/1000,vz3_D,yerr=err3_D,ecolor='black', color='orangered',label='Giant stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax4.tick_params(axis='y')
ax4.axhline(y=0,color='grey')
ax4.legend(fontsize=9,loc=1)

#Axis E


ax5.errorbar(y1_E/1000,vz1_E,yerr=err1_E,ecolor='black',color='mediumvioletred',label='OB stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax5.errorbar(y2_E/1000,vz2_E,yerr=err2_E,ecolor='black', color='blue',label='UMS stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax5.errorbar(y3_E/1000,vz3_E,yerr=err3_E,ecolor='black', color='orangered',label='Giant stars',ms=5,
capsize=3,elinewidth=2, markeredgewidth=2,fmt='s')

ax5.tick_params(axis='y')
ax5.axhline(y=0,color='grey')
ax5.legend(fontsize=9,loc=1)


ax1.set_yticks(np.arange(-6,6.5,3))
ax2.set_yticks(np.arange(-6,6.5,3))
ax3.set_yticks(np.arange(-6,6.5,3))
ax4.set_yticks(np.arange(-6,6.5,3))
ax5.set_yticks(np.arange(-6,6.5,3))

ax5.set_xticks(np.arange(-3,3.5,1))
plt.ylim(-7,7)

ax1.set_ylabel('$\widetilde{V_{z}^{\prime}}$ (km/s)',fontsize=18)
ax2.set_ylabel('$\widetilde{V_{z}^{\prime}}$(km/s)',fontsize=18)
ax3.set_ylabel('$\widetilde{V_{z}^{\prime}}$ (km/s)',fontsize=18)
ax4.set_ylabel('$\widetilde{V_{z}^{\prime}}$ (km/s)',fontsize=18)
ax5.set_ylabel('$\widetilde{V_{z}^{\prime}}$ (km/s)',fontsize=18)
plt.xlabel('$Y^{\prime}(kpc)$',fontsize=18)


ax1.text(-2.7,5.2,'A',horizontalalignment='center',c='black',fontsize=18,fontweight='bold')
ax2.text(-2.7,5.2,'B',horizontalalignment='center',c='black',fontsize=18,fontweight='bold')
ax3.text(-2.7,5.2,'C',horizontalalignment='center',c='black',fontsize=18,fontweight='bold')
ax4.text(-2.7,5.2,'D',horizontalalignment='center',c='black',fontsize=18,fontweight='bold')
ax5.text(-2.7,5.2,'E',horizontalalignment='center',c='black',fontsize=18,fontweight='bold')


sns.set_context("talk")
sns.set_style("white")

plt.show()

# %%
import pandas
d = { 'Giants': vz3_C, 'OB':vz1_C,'UMS':vz2_C}
df= pd.DataFrame(data=d)

# %%
df.corr().round(2)
# Out:
#         Giants    OB   UMS
# Giants    1.00 -0.38 -0.17
# OB       -0.38  1.00  0.78
# UMS      -0.17  0.78  1.00

# %%
corrs = df.corr()
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corrs, cmap='Spectral_r', square=True, vmin=-1, vmax=1)
sns.set_context("talk")
sns.set_style("white")
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %%
import pingouin as pg
import pandas
# Out:
# /Users/lekshmithulasidharan/opt/anaconda3/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package pingouin is out of date. Your version is 0.5.0, the latest is 0.5.5.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(

# %%
df.rcorr(stars=False)
# Out:
# /Users/lekshmithulasidharan/opt/anaconda3/lib/python3.8/site-packages/outdated/utils.py:14: OutdatedPackageWarning: The package outdated is out of date. Your version is 0.2.1, the latest is 0.2.2.
# Set the environment variable OUTDATED_IGNORE=1 to disable these warnings.
#   return warn(
#         Giants     OB    UMS
# Giants       -  0.130  0.527
# OB      -0.382      -  0.000
# UMS     -0.165   0.78      -

# %%
pg.corr(x=vz1_C, y=vz2_C) #OB and UMS
# Out:
#           n         r         CI95%     p-val     BF10     power
# pearson  17  0.780363  [0.48, 0.92]  0.000219  157.831  0.979268

# %%
pg.corr(x=vz1_C, y=vz3_C) #OB and giants
# Out:
#           n         r          CI95%     p-val   BF10     power
# pearson  17 -0.382212  [-0.73, 0.12]  0.130017  0.866  0.338916

# %%
pg.corr(x=vz2_C, y=vz3_C) #UMS and giants
# Out:
#           n         r         CI95%     p-val   BF10     power
# pearson  17 -0.165025  [-0.6, 0.34]  0.526765  0.361  0.097147
